# %% [markdown]
# Why we need Pandas?
#
# In a dataset, there are different columns representing features. Pandas manages tabular data more efficiently.
#
# What can we do with Pandas?
#
# * Import datasets (CSV, Excel, SQL)
# * Data cleansing (Missing values, Invalid values)
# * Size mutability (Add / Delete rows/columns)
# * Reshaping and pivoting of datasets
# * Efficient manipulation and extraction
# * Statistical analysis
#
# Two primary data structures available in Pandas:
#
# * Series (1-Dimensional - Represents a single column) - A one-dimensional labeled homogeneous array, size immutable. The columns items (each row) is identified by an index.
# * Dataframe (2-Dimensional) - A two-dimensional labeled, size-mutable tabular structure with heterogeneously types columns.
#
# Data structure are collections of data types that provide the best way of organizing item (or values) in terms of memory usage.
#
#
# https://www.youtube.com/watch?v=vtgDGrUiUKk&t=5s

# %%
import pandas as pd
import numpy as np

s = pd.Series([10, 20, 30, 40, 50])

print(s)

s1 = pd.Series([10, 20, 30, 40, "Atanu"])

print(s1)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64
# 0       10
# 1       20
# 2       30
# 3       40
# 4    Atanu
# dtype: object

# %%
import pandas as pd
import numpy as np

s = pd.Series([10, 20, 30, 40, 50])

print(s.dtype)

s1 = pd.Series([10, 20, 30, 40, "Atanu"])

print(s1.dtype)
# Out:
# int64
# object

# %%
import pandas as pd
import numpy as np

s = pd.Series([10, 20, 30, 40, 50])

print(s.values)

s1 = pd.Series([10, 20, 30, 40, "Atanu"])

print(s1.values)
# Out:
# [10 20 30 40 50]
# [10 20 30 40 'Atanu']

# %%
import pandas as pd
import numpy as np

# index always starts with 0 and ends with the last position number included.

s = pd.Series([10, 20, 30, 40, 50])

print(s.index)
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
# To assign a name to the column and show it. 

import pandas as pd
import numpy as np

s = pd.Series([10, 20, 30, 40, 50])
s.name = "Multiples of ten"

print(s)

print(s.name)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# Name: Multiples of ten, dtype: int64
# Multiples of ten

# %% [markdown]
# Indexing

# %%
import pandas as pd
import numpy as np

s = pd.Series([10, 20, 30, 40, 50])

print(s[0])

print(s[0:2]) # start (included) end (not included) step value (values to jump)
print(s[2:4])
# Out:
# 10
# 0    10
# 1    20
# dtype: int64
# 2    30
# 3    40
# dtype: int64

# %% [markdown]
# iloc - Location based indexing

# %%
import pandas as pd
import numpy as np

s = pd.Series([10, 20, 30, 40, 50])

print(s.iloc[3])

print(s.iloc[[1, 3, 4]])
# Out:
# 40
# 1    20
# 3    40
# 4    50
# dtype: int64

# %%
import pandas as pd
import numpy as np

s = pd.Series([10, 20, 30, 40, 50])
s.name = "Calories"

index = ["apple", "banana", "grapes", "orange", "strawberry"]

s.index = index

print(s)

print(s['grapes'])

# Here, iloc cannot be used by refereing the names of the indexes. It can still be used by referengin the index number.
print(s.iloc[3])
# Out:
# apple         10
# banana        20
# grapes        30
# orange        40
# strawberry    50
# Name: Calories, dtype: int64
# 30
# 40

# %% [markdown]
# loc function - label based indexing
#
# Label Based Indexes - Here, you start and end values -both are included.

# %%
import pandas as pd
import numpy as np

s = pd.Series([10, 20, 30, 40, 50])
s.name = "Calories"

index = ["apple", "banana", "grapes", "orange", "strawberry"]

s.index = index

print(s)

print(s.loc['banana'])

print(s['banana':'orange'])

print(s.loc[['grapes', 'apple']])
# Out:
# apple         10
# banana        20
# grapes        30
# orange        40
# strawberry    50
# Name: Calories, dtype: int64
# 20
# banana    20
# grapes    30
# orange    40
# Name: Calories, dtype: int64
# grapes    30
# apple     10
# Name: Calories, dtype: int64

# %% [markdown]
# Creating a Series using Dictionary

# %%
import pandas as pd
import numpy as np

# grams of protein

fruit_protein = {
    "Avocado": 2.0,
    "Guava": 2.6,
    "Blackberries": 2.0,
    "Oranges": 0.9,
    "Banana": 1.1,
    "Apples": 0.3,
    "Kiwi": 1.1,
    "Pomegranate": 1.7,
    "Mango": 0.8,
    "Cherries": 1.0
}

s2 = pd.Series(fruit_protein, name="Protein")

print(s2)
# Out:
# Avocado         2.0
# Guava           2.6
# Blackberries    2.0
# Oranges         0.9
# Banana          1.1
# Apples          0.3
# Kiwi            1.1
# Pomegranate     1.7
# Mango           0.8
# Cherries        1.0
# Name: Protein, dtype: float64

# %% [markdown]
# Conditional Selection

# %%
import pandas as pd
import numpy as np

print(s2>1)
# Out:
# Avocado          True
# Guava            True
# Blackberries     True
# Oranges         False
# Banana           True
# Apples          False
# Kiwi             True
# Pomegranate      True
# Mango           False
# Cherries        False
# Name: Protein, dtype: bool

# %%
import pandas as pd
import numpy as np

print(s2[s2>1])
# Out:
# Avocado         2.0
# Guava           2.6
# Blackberries    2.0
# Banana          1.1
# Kiwi            1.1
# Pomegranate     1.7
# Name: Protein, dtype: float64

# %% [markdown]
# Logical Operators: AND / OR / NOT

# %%
import pandas as pd
import numpy as np

# grams of protein

fruit_protein = {
    "Avocado": 2.0,
    "Guava": 2.6,
    "Blackberries": 2.0,
    "Oranges": 0.9,
    "Banana": 1.1,
    "Apples": 0.3,
    "Kiwi": 1.1,
    "Pomegranate": 1.7,
    "Mango": 0.8,
    "Cherries": 1.0
}

s2 = pd.Series(fruit_protein, name="Protein")

print(s2[(s2>0.5) & (s2<=2)]) # AND operation

print(s2[(s2>0.5) | (s2<=2)]) # OR operation

print(s2[~(s2>1)]) # NOT operation
# Out:
# Avocado         2.0
# Blackberries    2.0
# Oranges         0.9
# Banana          1.1
# Kiwi            1.1
# Pomegranate     1.7
# Mango           0.8
# Cherries        1.0
# Name: Protein, dtype: float64
# Avocado         2.0
# Guava           2.6
# Blackberries    2.0
# Oranges         0.9
# Banana          1.1
# Apples          0.3
# Kiwi            1.1
# Pomegranate     1.7
# Mango           0.8
# Cherries        1.0
# Name: Protein, dtype: float64
# Oranges     0.9
# Apples      0.3
# Mango       0.8
# Cherries    1.0
# Name: Protein, dtype: float64

# %% [markdown]
# Modifying the Series

# %%
import pandas as pd
import numpy as np

# grams of protein

fruit_protein = {
    "Avocado": 2.0,
    "Guava": 2.6,
    "Blackberries": 2.0,
    "Oranges": 0.9,
    "Banana": 1.1,
    "Apples": 0.3,
    "Kiwi": 1.1,
    "Pomegranate": 1.7,
    "Mango": 0.8,
    "Cherries": 1.0
}

s2 = pd.Series(fruit_protein, name="Protein")

s2["Mango"] = 2.8

print(s2)
# Out:
# Avocado         2.0
# Guava           2.6
# Blackberries    2.0
# Oranges         0.9
# Banana          1.1
# Apples          0.3
# Kiwi            1.1
# Pomegranate     1.7
# Mango           2.8
# Cherries        1.0
# Name: Protein, dtype: float64

# %% [markdown]
# https://www.youtube.com/watch?v=vtgDGrUiUKk&t=5s

# %% [markdown]
# Data Frames

# %%
import pandas as pd
import numpy as np

data1 = {
    "Name": ["Alice", "Bob", "Charlie", "David", "Eve", "Alice"],
    "Age": [25, 30, 35, np.nan, 29, 25],
    "Department": ["HR", "IT", "Finance", "IT", "HR", "HR"],
    "Salary": [50000, 60000, 70000, 62000, np.nan, 50000]
}

df = pd.DataFrame(data1)

print(df)

print(df.head(2))
# Out:
#       Name   Age Department   Salary
# 0    Alice  25.0         HR  50000.0
# 1      Bob  30.0         IT  60000.0
# 2  Charlie  35.0    Finance  70000.0
# 3    David   NaN         IT  62000.0
# 4      Eve  29.0         HR      NaN
# 5    Alice  25.0         HR  50000.0
#     Name   Age Department   Salary
# 0  Alice  25.0         HR  50000.0
# 1    Bob  30.0         IT  60000.0

# %%
import pandas as pd
import numpy as np

data1 = {
    "Name": ["Alice", "Bob", "Charlie", "David", "Eve", "Alice"],
    "Age": [25, 30, 35, np.nan, 29, 25],
    "Department": ["HR", "IT", "Finance", "IT", "HR", "HR"],
    "Salary": [50000, 60000, 70000, 62000, np.nan, 50000]
}

df = pd.DataFrame(data1)

print(df.head())

print(df.tail(3))
# Out:
#       Name   Age Department   Salary
# 0    Alice  25.0         HR  50000.0
# 1      Bob  30.0         IT  60000.0
# 2  Charlie  35.0    Finance  70000.0
# 3    David   NaN         IT  62000.0
# 4      Eve  29.0         HR      NaN
#     Name   Age Department   Salary
# 3  David   NaN         IT  62000.0
# 4    Eve  29.0         HR      NaN
# 5  Alice  25.0         HR  50000.0

# %% [markdown]
# loc and iloc functions

# %%
import pandas as pd
import numpy as np

data1 = {
    "Name": ["Alice", "Bob", "Charlie", "David", "Eve", "Alice"],
    "Age": [25, 30, 35, np.nan, 29, 25],
    "Department": ["HR", "IT", "Finance", "IT", "HR", "HR"],
    "Salary": [50000, 60000, 70000, 62000, np.nan, 50000]
}

df = pd.DataFrame(data1)

print(df.iloc[1:3])

print(df.iloc[1:3, :2])
# Out:
#       Name   Age Department   Salary
# 1      Bob  30.0         IT  60000.0
# 2  Charlie  35.0    Finance  70000.0
#       Name   Age
# 1      Bob  30.0
# 2  Charlie  35.0

# %%
import pandas as pd
import numpy as np

data1 = {
    "Name": ["Alice", "Bob", "Charlie", "David", "Eve", "Alice"],
    "Age": [25, 30, 35, np.nan, 29, 25],
    "Department": ["HR", "IT", "Finance", "IT", "HR", "HR"],
    "Salary": [50000, 60000, 70000, 62000, np.nan, 50000]
}

df = pd.DataFrame(data1)

print(df.loc[1:3, ["Age", "Department"]])
# Out:
#     Age Department
# 1  30.0         IT
# 2  35.0    Finance
# 3   NaN         IT

# %%
# Accessing individual column

import pandas as pd
import numpy as np

data1 = {
    "Name": ["Alice", "Bob", "Charlie", "David", "Eve", "Alice"],
    "Age": [25, 30, 35, np.nan, 29, 25],
    "Department": ["HR", "IT", "Finance", "IT", "HR", "HR"],
    "Salary": [50000, 60000, 70000, 62000, np.nan, 50000]
}

print(pd.DataFrame(data1)["Age"])
# Out:
# 0    25.0
# 1    30.0
# 2    35.0
# 3     NaN
# 4    29.0
# 5    25.0
# Name: Age, dtype: float64

# %%
# Accessing multiple columns

import pandas as pd
import numpy as np

data1 = {
    "Name": ["Alice", "Bob", "Charlie", "David", "Eve", "Alice"],
    "Age": [25, 30, 35, np.nan, 29, 25],
    "Department": ["HR", "IT", "Finance", "IT", "HR", "HR"],
    "Salary": [50000, 60000, 70000, 62000, np.nan, 50000]
}

print(pd.DataFrame(data1)[["Age", "Department"]])
# Out:
#     Age Department
# 0  25.0         HR
# 1  30.0         IT
# 2  35.0    Finance
# 3   NaN         IT
# 4  29.0         HR
# 5  25.0         HR

# %% [markdown]
# Drop Individual Column

# %%
import pandas as pd
import numpy as np

data1 = {
    "Name": ["Alice", "Bob", "Charlie", "David", "Eve", "Alice"],
    "Age": [25, 30, 35, np.nan, 29, 25],
    "Department": ["HR", "IT", "Finance", "IT", "HR", "HR"],
    "Salary": [50000, 60000, 70000, 62000, np.nan, 50000]
}

print(pd.DataFrame(data1).drop("Age", axis=1))
print(pd.DataFrame(data1))
# Out:
#       Name Department   Salary
# 0    Alice         HR  50000.0
# 1      Bob         IT  60000.0
# 2  Charlie    Finance  70000.0
# 3    David         IT  62000.0
# 4      Eve         HR      NaN
# 5    Alice         HR  50000.0
#       Name   Age Department   Salary
# 0    Alice  25.0         HR  50000.0
# 1      Bob  30.0         IT  60000.0
# 2  Charlie  35.0    Finance  70000.0
# 3    David   NaN         IT  62000.0
# 4      Eve  29.0         HR      NaN
# 5    Alice  25.0         HR  50000.0

# %%
# Caution: If we want to drop the entire column "Age" in the original dataframe, use the parameter: inplace

import pandas as pd
import numpy as np

data2 = {
    "Name": ["Alice", "Bob", "Charlie", "David", "Eve", "Alice"],
    "Age": [25, 30, 35, np.nan, 29, 25],
    "Department": ["HR", "IT", "Finance", "IT", "HR", "HR"],
    "Salary": [50000, 60000, 70000, 62000, np.nan, 50000]
}

df = pd.DataFrame(data2)
df.drop("Age", axis=1, inplace=True)
print(df)
# Out:
#       Name Department   Salary
# 0    Alice         HR  50000.0
# 1      Bob         IT  60000.0
# 2  Charlie    Finance  70000.0
# 3    David         IT  62000.0
# 4      Eve         HR      NaN
# 5    Alice         HR  50000.0

# %%
import pandas as pd
import numpy as np

data2 = {
    "Name": ["Alice", "Bob", "Charlie", "David", "Eve", "Alice"],
    "Age": [25, 30, 35, np.nan, 29, 25],
    "Department": ["HR", "IT", "Finance", "IT", "HR", "HR"],
    "Salary": [50000, 60000, 70000, 62000, np.nan, 50000]
}

df = pd.DataFrame(data2)

# Indexes are not counted as part of the column

print(df.shape)
print(df.info())
print(df.describe())
# Out:
# (6, 4)
# <class 'pandas.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        6 non-null      str
#  1   Age         5 non-null      float64
#  2   Department  6 non-null      str
#  3   Salary      5 non-null      float64
# dtypes: float64(2), str(2)
# memory usage: 324.0 bytes
# None
#              Age        Salary
# count   5.000000      5.000000
# mean   28.800000  58400.000000
# std     4.147288   8532.291603
# min    25.000000  50000.000000
# 25%    25.000000  50000.000000
# 50%    29.000000  60000.000000
# 75%    30.000000  62000.000000
# max    35.000000  70000.000000

# %% [markdown]
# Broadcasting

# %%
import pandas as pd
import numpy as np

data2 = {
    "Name": ["Alice", "Bob", "Charlie", "David", "Eve", "Alice"],
    "Age": [25, 30, 35, np.nan, 29, 25],
    "Department": ["HR", "IT", "Finance", "IT", "HR", "HR"],
    "Salary": [50000, 60000, 70000, 62000, np.nan, 50000]
}

df = pd.DataFrame(data2)

df["Salary"] = df["Salary"] + 5000
print(df["Salary"])
print(df)
# Out:
# 0    55000.0
# 1    65000.0
# 2    75000.0
# 3    67000.0
# 4        NaN
# 5    55000.0
# Name: Salary, dtype: float64
#       Name   Age Department   Salary
# 0    Alice  25.0         HR  55000.0
# 1      Bob  30.0         IT  65000.0
# 2  Charlie  35.0    Finance  75000.0
# 3    David   NaN         IT  67000.0
# 4      Eve  29.0         HR      NaN
# 5    Alice  25.0         HR  55000.0

# %% [markdown]
# Renaming Columns

# %%
import pandas as pd
import numpy as np

data2 = {
    "Name": ["Alice", "Bob", "Charlie", "David", "Eve", "Alice"],
    "Age": [25, 30, 35, np.nan, 29, 25],
    "Department": ["HR", "IT", "Finance", "IT", "HR", "HR"],
    "Salary": [50000, 60000, 70000, 62000, np.nan, 50000]
}

df = pd.DataFrame(data2)

df.rename(columns = {"Department": "Dept."}, inplace = True)

print(df)
# Out:
#       Name   Age    Dept.   Salary
# 0    Alice  25.0       HR  50000.0
# 1      Bob  30.0       IT  60000.0
# 2  Charlie  35.0  Finance  70000.0
# 3    David   NaN       IT  62000.0
# 4      Eve  29.0       HR      NaN
# 5    Alice  25.0       HR  50000.0

# %% [markdown]
# To check unique values

# %%
import pandas as pd
import numpy as np

data2 = {
    "Name": ["Alice", "Bob", "Charlie", "David", "Eve", "Alice"],
    "Age": [25, 30, 35, np.nan, 29, 25],
    "Department": ["HR", "IT", "Finance", "IT", "HR", "HR"],
    "Salary": [50000, 60000, 70000, 62000, np.nan, 50000]
}

df = pd.DataFrame(data2)

print(df["Salary"].unique())

print(df["Department"].unique())

print(df["Department"].value_counts())
# Out:
# [50000. 60000. 70000. 62000.    nan]
# <StringArray>
# ['HR', 'IT', 'Finance']
# Length: 3, dtype: str
# Department
# HR         3
# IT         2
# Finance    1
# Name: count, dtype: int64

# %% [markdown]
# Adding New Column

# %%
import pandas as pd
import numpy as np

data2 = {
    "Name": ["Alice", "Bob", "Charlie", "David", "Eve", "Alice"],
    "Age": [25, 30, 35, np.nan, 29, 25],
    "Department": ["HR", "IT", "Finance", "IT", "HR", "HR"],
    "Salary": [50000, 60000, 70000, 62000, np.nan, 50000]
}

df = pd.DataFrame(data2)

df["Promoted Salary"] = df["Salary"] * 10

print(df)
# Out:
#       Name   Age Department   Salary  Promoted Salary
# 0    Alice  25.0         HR  50000.0         500000.0
# 1      Bob  30.0         IT  60000.0         600000.0
# 2  Charlie  35.0    Finance  70000.0         700000.0
# 3    David   NaN         IT  62000.0         620000.0
# 4      Eve  29.0         HR      NaN              NaN
# 5    Alice  25.0         HR  50000.0         500000.0

# %% [markdown]
# Data Cleaning

# %%
import pandas as pd
import numpy as np

data3 = {
    "Name": ["Alice", "Bob", "Charlie", "David", "Eve", "Alice"],
    "Age": [25, 30, 35, np.nan, 29, 25],
    "Department": ["HR", "IT", "Finance", "IT", "HR", "HR"],
    "Salary": [50000, 60000, 70000, 62000, np.nan, 50000],
    "Promoted Salary": [500000, 600000, 700000, 620000, np.nan, 500000]
}

df = pd.DataFrame(data3)

print(df.isnull())

print(df.isnull().sum())
# Out:
#     Name    Age  Department  Salary  Promoted Salary
# 0  False  False       False   False            False
# 1  False  False       False   False            False
# 2  False  False       False   False            False
# 3  False   True       False   False            False
# 4  False  False       False    True             True
# 5  False  False       False   False            False
# Name               0
# Age                1
# Department         0
# Salary             1
# Promoted Salary    1
# dtype: int64

# %%
# To drop any rows that is having null values

import pandas as pd
import numpy as np

data3 = {
    "Name": ["Alice", "Bob", "Charlie", "David", "Eve", "Alice"],
    "Age": [25, 30, 35, np.nan, 29, 25],
    "Department": ["HR", "IT", "Finance", "IT", "HR", "HR"],
    "Salary": [50000, 60000, 70000, 62000, np.nan, 50000],
    "Promoted Salary": [500000, 600000, 700000, 620000, np.nan, 500000]
}

df = pd.DataFrame(data3)
print(df.dropna()) # This is equivalent to df.dropna(how = "any") | Any row that has a null value

print(df)
# Out:
#       Name   Age Department   Salary  Promoted Salary
# 0    Alice  25.0         HR  50000.0         500000.0
# 1      Bob  30.0         IT  60000.0         600000.0
# 2  Charlie  35.0    Finance  70000.0         700000.0
# 5    Alice  25.0         HR  50000.0         500000.0
#       Name   Age Department   Salary  Promoted Salary
# 0    Alice  25.0         HR  50000.0         500000.0
# 1      Bob  30.0         IT  60000.0         600000.0
# 2  Charlie  35.0    Finance  70000.0         700000.0
# 3    David   NaN         IT  62000.0         620000.0
# 4      Eve  29.0         HR      NaN              NaN
# 5    Alice  25.0         HR  50000.0         500000.0

# %%
import pandas as pd
import numpy as np

data3 = {
    "Name": ["Alice", "Bob", "Charlie", "David", "Eve", "Alice"],
    "Age": [25, 30, 35, np.nan, 29, 25],
    "Department": ["HR", "IT", "Finance", "IT", "HR", "HR"],
    "Salary": [50000, 60000, 70000, 62000, np.nan, 50000],
    "Promoted Salary": [500000, 600000, 700000, 620000, np.nan, 500000]
}

df = pd.DataFrame(data3)
print(df.dropna(how = "all")) # If a row has all null values, then drop that row

print(df)
# Out:
#       Name   Age Department   Salary  Promoted Salary
# 0    Alice  25.0         HR  50000.0         500000.0
# 1      Bob  30.0         IT  60000.0         600000.0
# 2  Charlie  35.0    Finance  70000.0         700000.0
# 3    David   NaN         IT  62000.0         620000.0
# 4      Eve  29.0         HR      NaN              NaN
# 5    Alice  25.0         HR  50000.0         500000.0
#       Name   Age Department   Salary  Promoted Salary
# 0    Alice  25.0         HR  50000.0         500000.0
# 1      Bob  30.0         IT  60000.0         600000.0
# 2  Charlie  35.0    Finance  70000.0         700000.0
# 3    David   NaN         IT  62000.0         620000.0
# 4      Eve  29.0         HR      NaN              NaN
# 5    Alice  25.0         HR  50000.0         500000.0

# %% [markdown]
# Filling Missing Values - fillna()

# %%
import pandas as pd
import numpy as np

data3 = {
    "Name": ["Alice", "Bob", "Charlie", "David", "Eve", "Alice"],
    "Age": [25, 30, 35, np.nan, 29, 25],
    "Department": ["HR", "IT", "Finance", "IT", "HR", "HR"],
    "Salary": [50000, 60000, 70000, 62000, np.nan, 50000],
    "Promoted Salary": [500000, 600000, 700000, 620000, np.nan, 500000]
}

df = pd.DataFrame(data3)

print(df.fillna(0))

print(df)
# Out:
#       Name   Age Department   Salary  Promoted Salary
# 0    Alice  25.0         HR  50000.0         500000.0
# 1      Bob  30.0         IT  60000.0         600000.0
# 2  Charlie  35.0    Finance  70000.0         700000.0
# 3    David   0.0         IT  62000.0         620000.0
# 4      Eve  29.0         HR      0.0              0.0
# 5    Alice  25.0         HR  50000.0         500000.0
#       Name   Age Department   Salary  Promoted Salary
# 0    Alice  25.0         HR  50000.0         500000.0
# 1      Bob  30.0         IT  60000.0         600000.0
# 2  Charlie  35.0    Finance  70000.0         700000.0
# 3    David   NaN         IT  62000.0         620000.0
# 4      Eve  29.0         HR      NaN              NaN
# 5    Alice  25.0         HR  50000.0         500000.0

# %%
# Filling the missing values in the Age column with the mean value

import pandas as pd
import numpy as np

data3 = {
    "Name": ["Alice", "Bob", "Charlie", "David", "Eve", "Alice"],
    "Age": [25, 30, 35, np.nan, 29, 25],
    "Department": ["HR", "IT", "Finance", "IT", "HR", "HR"],
    "Salary": [50000, 60000, 70000, 62000, np.nan, 50000],
    "Promoted Salary": [500000, 600000, 700000, 620000, np.nan, 500000]
}

df = pd.DataFrame(data3)

print(df["Age"].fillna(df["Age"].mean())) # Here, "inplace = True" is not used.

print(df)
# Out:
# 0    25.0
# 1    30.0
# 2    35.0
# 3    28.8
# 4    29.0
# 5    25.0
# Name: Age, dtype: float64
#       Name   Age Department   Salary  Promoted Salary
# 0    Alice  25.0         HR  50000.0         500000.0
# 1      Bob  30.0         IT  60000.0         600000.0
# 2  Charlie  35.0    Finance  70000.0         700000.0
# 3    David   NaN         IT  62000.0         620000.0
# 4      Eve  29.0         HR      NaN              NaN
# 5    Alice  25.0         HR  50000.0         500000.0

# %%
# Filling the missing values in the Salary column with the median value

import pandas as pd
import numpy as np

data3 = {
    "Name": ["Alice", "Bob", "Charlie", "David", "Eve", "Alice"],
    "Age": [25, 30, 35, np.nan, 29, 25],
    "Department": ["HR", "IT", "Finance", "IT", "HR", "HR"],
    "Salary": [55000, 65000, 75000, 67000, np.nan, 55000],
}

df = pd.DataFrame(data3)

print(df["Salary"].fillna(df["Salary"].median())) # Here, "inplace = True" is not used.

print(df)
# Out:
# 0    55000.0
# 1    65000.0
# 2    75000.0
# 3    67000.0
# 4    65000.0
# 5    55000.0
# Name: Salary, dtype: float64
#       Name   Age Department   Salary
# 0    Alice  25.0         HR  55000.0
# 1      Bob  30.0         IT  65000.0
# 2  Charlie  35.0    Finance  75000.0
# 3    David   NaN         IT  67000.0
# 4      Eve  29.0         HR      NaN
# 5    Alice  25.0         HR  55000.0

# %% [markdown]
# https://youtu.be/vtgDGrUiUKk?t=2648

# %% [markdown]
# Forward Fill / Backward Fill

# %%
import pandas as pd
import numpy as np

data3 = {
    "Name": ["Alice", "Bob", "Charlie", "David", "Eve", "Alice"],
    "Age": [25, 30, 35, np.nan, 29, 25],
    "Department": ["HR", "IT", "Finance", "IT", "HR", "HR"],
    "Salary": [55000, 65000, 75000, 67000, np.nan, 55000],
}

df = pd.DataFrame(data3)

print(df["Age"].ffill()) # Here, "inplace = True" is not used.
print(df["Age"].bfill()) # Here, "inplace = True" is not used.
# Out:
# 0    25.0
# 1    30.0
# 2    35.0
# 3    35.0
# 4    29.0
# 5    25.0
# Name: Age, dtype: float64
# 0    25.0
# 1    30.0
# 2    35.0
# 3    29.0
# 4    29.0
# 5    25.0
# Name: Age, dtype: float64

# %% [markdown]
# Replace Value

# %%
import pandas as pd
import numpy as np

data3 = {
    "Name": ["Alice", "Bob", "Charlie", "David", "Eve", "Alice"],
    "Age": [25, 30, 35, np.nan, 29, 25],
    "Department": ["HR", "IT", "Finance", "IT", "HR", "HR"],
    "Salary": [55000, 65000, 75000, 67000, np.nan, 55000],
}

df = pd.DataFrame(data3)

print(df["Name"].replace("Charlie", "Rose"))
print(df)
# Out:
# 0    Alice
# 1      Bob
# 2     Rose
# 3    David
# 4      Eve
# 5    Alice
# Name: Name, dtype: str
#       Name   Age Department   Salary
# 0    Alice  25.0         HR  55000.0
# 1      Bob  30.0         IT  65000.0
# 2  Charlie  35.0    Finance  75000.0
# 3    David   NaN         IT  67000.0
# 4      Eve  29.0         HR      NaN
# 5    Alice  25.0         HR  55000.0

# %%
# To commit in the DF (Permanent Change)

import pandas as pd
import numpy as np

data3 = {
    "Name": ["Alice", "Bob", "Charlie", "David", "Eve", "Alice"],
    "Age": [25, 30, 35, np.nan, 29, 25],
    "Department": ["HR", "IT", "Finance", "IT", "HR", "HR"],
    "Salary": [55000, 65000, 75000, 67000, np.nan, 55000],
}

df = pd.DataFrame(data3)

df["Name"] = df["Name"].replace("Charlie", "Rose")
print(df)
# Out:
#     Name   Age Department   Salary
# 0  Alice  25.0         HR  55000.0
# 1    Bob  30.0         IT  65000.0
# 2   Rose  35.0    Finance  75000.0
# 3  David   NaN         IT  67000.0
# 4    Eve  29.0         HR      NaN
# 5  Alice  25.0         HR  55000.0

# %% [markdown]
# Duplicate Data

# %%
import pandas as pd
import numpy as np

data3 = {
    "Name": ["Alice", "Bob", "Charlie", "David", "Eve", "Alice"],
    "Age": [25, 30, 35, np.nan, 29, 25],
    "Department": ["HR", "IT", "Finance", "IT", "HR", "HR"],
    "Salary": [55000, 65000, 75000, 67000, np.nan, 55000],
}

df = pd.DataFrame(data3)

# df_dup = df[df.duplicated(keep = "last")] - The last record will be kept as unique and the first record/s will be marked as duplicate
df_dup = df[df.duplicated(keep = "first")] # The first record will be kept as unique and the last or thereafter record/s will be marked as duplicate

print(df_dup)
# Out:
#     Name   Age Department   Salary
# 5  Alice  25.0         HR  55000.0

# %% [markdown]
# Remove Duplicate Values

# %%
import pandas as pd
import numpy as np

data3 = {
    "Name": ["Alice", "Bob", "Charlie", "David", "Eve", "Alice"],
    "Age": [25, 30, 35, np.nan, 29, 25],
    "Department": ["HR", "IT", "Finance", "IT", "HR", "HR"],
    "Salary": [55000, 65000, 75000, 67000, np.nan, 55000],
}

df = pd.DataFrame(data3)

df = df.drop_duplicates()

print(df)
# Out:
#       Name   Age Department   Salary
# 0    Alice  25.0         HR  55000.0
# 1      Bob  30.0         IT  65000.0
# 2  Charlie  35.0    Finance  75000.0
# 3    David   NaN         IT  67000.0
# 4      Eve  29.0         HR      NaN

# %% [markdown]
# Lambda Function

# %%
import pandas as pd
import numpy as np

data3 = {
    "Name": ["Alice", "Bob", "Charlie", "David", "Eve", "Alice"],
    "Age": [25, 30, 35, np.nan, 29, 25],
    "Department": ["HR", "IT", "Finance", "IT", "HR", "HR"],
    "Salary": [50000, 60000, 70000, 62000, np.nan, 50000],
    "Promoted Salary": [500000, 600000, 700000, 620000, np.nan, 500000]
}

df = pd.DataFrame(data3)

df["Promoted Salary"] = df["Promoted Salary"].apply(lambda x: x/10 if x > 650000 else x)

print(df)
# Out:
#       Name   Age Department   Salary  Promoted Salary
# 0    Alice  25.0         HR  50000.0         500000.0
# 1      Bob  30.0         IT  60000.0         600000.0
# 2  Charlie  35.0    Finance  70000.0          70000.0
# 3    David   NaN         IT  62000.0         620000.0
# 4      Eve  29.0         HR      NaN              NaN
# 5    Alice  25.0         HR  50000.0         500000.0

# %% [markdown]
# String Functions

# %%
# Split String Function

import pandas as pd
import numpy as np

data3 = {
    "Name": ["Alice_Brown", "Bob", "Charlie", "David", "Eve", "Alice"],
    "Age": [25, 30, 35, np.nan, 29, 25],
    "Department": ["HR", "IT", "Finance", "IT", "HR", "HR"],
    "Salary": [50000, 60000, 70000, 62000, np.nan, 50000],
    "Promoted Salary": [500000, 600000, 700000, 620000, np.nan, 500000]
}

df = pd.DataFrame(data3)

df[["first_name", "last_name"]] = df["Name"].str.split("_") # Here the splitting will be on the delimiter "_"

print(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_41168\3752739409.py in ?()
#      12 }
#      13
#      14 df = pd.DataFrame(data3)
#      15
# ---> 16 df[["first_name", "last_name"]] = df["Name"].str.split("_") # Here the splitting will be on the delimiter "_"
#      17
#      18 print(df)
#
# c:\Users\ADMIN\Documents\Week 1\Python Programs\.venv\Lib\site-packages\pandas\core\frame.py in ?(self, key, value)
#    4656
#    4657         if isinstance(key, DataFrame) or getattr(key, "ndim", None) == 2:
#    4658             self._setitem_frame(key, value)
#    4659         elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 4660             self._setitem_array(key, value)
#    4661         elif isinstance(value, DataFrame):
#    4662             self._set_item_frame_value(key, value)
#    4663         elif (
#
# ...

# %% [markdown]
# apply and lambda examples

# %%
import pandas as pd
import numpy as np

data3 = {
    "Name": ["Alice_Brown", "Bob", "Charlie", "David", "Eve", "Alice"],
    "Age": [25, 30, 35, np.nan, 29, 25],
    "Department": ["HR", "IT", "Finance", "IT", "HR", "HR"],
    "Salary": [50000, 60000, 70000, 62000, np.nan, 50000],
    "Promoted Salary": [500000, 600000, 700000, 620000, np.nan, 500000]
}

df = pd.DataFrame(data3)

def multiplying_age(x):
    return x*2

df["Age"] = df["Age"].apply(multiplying_age)

print(df)

df["Age"] = df["Age"].apply(lambda x: x/2)

print(df)
# Out:
#           Name   Age Department   Salary  Promoted Salary
# 0  Alice_Brown  50.0         HR  50000.0         500000.0
# 1          Bob  60.0         IT  60000.0         600000.0
# 2      Charlie  70.0    Finance  70000.0         700000.0
# 3        David   NaN         IT  62000.0         620000.0
# 4          Eve  58.0         HR      NaN              NaN
# 5        Alice  50.0         HR  50000.0         500000.0
#           Name   Age Department   Salary  Promoted Salary
# 0  Alice_Brown  25.0         HR  50000.0         500000.0
# 1          Bob  30.0         IT  60000.0         600000.0
# 2      Charlie  35.0    Finance  70000.0         700000.0
# 3        David   NaN         IT  62000.0         620000.0
# 4          Eve  29.0         HR      NaN              NaN
# 5        Alice  25.0         HR  50000.0         500000.0

# %% [markdown]
# Joins & Merges
#
# Joins - left, right, outer, inner joins
